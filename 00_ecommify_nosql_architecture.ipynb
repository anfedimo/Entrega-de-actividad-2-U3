# %%
# 1. Instalación de la biblioteca requerida
# !pip install pymongo dnspython

# 2. Importación de módulos
from pymongo import MongoClient

# 3. NUEVA Cadena de conexión ensamblada (¡Host actualizado!)
uri = "mongodb+srv://falconorion92_db_user:QOZmqqBpvnYARhLg@ecommify.unsubcg.mongodb.net/?retryWrites=true&w=majority&appName=Ecommify"

try:
    # 4. Inicializamos el cliente
    client = MongoClient(uri, serverSelectionTimeoutMS=10000)

    # 5. Forzamos un 'ping' para validar conectividad
    client.admin.command('ping')
    print("✅ ¡ÉXITO! Conexión establecida correctamente con el clúster 'ecommify.unsubcg'.")

    # 6. Instanciamos la base de datos de Ecommify
    db = client['ecommify_db']
    print(f"✅ Base de datos lista: {db.name}")

except Exception as e:
    print(f"❌ ERROR DE CONEXIÓN: {e}")
